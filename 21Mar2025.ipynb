    17: [],
    18: [],
    19: ["2025-03-23_03-18-39-A7AD2596-97B7-46F5-B741-7AFC0ACB54AB-ble-arkit-log", "2025-03-23_03-19-41-5F6FBE74-EF31-4545-956C-D8AD199BC072-ble-arkit-log", "2025-03-23_03-20-48-20B7A7A0-7910-4240-A51E-307C836B3B75-ble-arkit-log", "2025-03-23_03-21-37-6EEFD694-6A0D-430E-A82C-5BA6D035FB21-ble-arkit-log", "2025-03-23_03-22-40-8BFF1455-E9B7-4F2F-B56C-0B741A43E4A7-ble-arkit-log"]
}
ARKIT_SCAN_GROUP = ScanGroup(Scan.load(f"{ARKIT_LOG_DIR}/{ARKIT_FIRST_SCAN}.json"))
for environmentID, filenames in ARKIT_SCANS.items():
    ARKIT_SCAN_GROUP.addScans(environmentID, [ Scan.load(f"{ARKIT_LOG_DIR}/{filename}.json") for filename in filenames])

ARCORE_FIRST_SCAN = "2025-03-22_00-06-42-C2690520-62A2-40A2-877D-AD641F80A406-ble-arcore-log"
ARCORE_SCANS = {
    0: ["2025-03-22_00-11-54-5D859FA8-DC48-4C81-AEE8-8AE241EF3862-ble-arcore-log", "2025-03-22_00-19-08-3E299A5D-2FC3-4319-AA90-591E33B4BF23-ble-arcore-log", "2025-03-22_00-24-50-D4DACE3E-84DF-4686-9722-48ED43E03302-ble-arcore-log", "2025-03-22_00-26-16-ADEB7FBD-98C4-4923-99CA-2FF45089314F-ble-arcore-log"],
    1: ["2025-03-22_15-14-23-75030C5F-D78E-4882-BFCB-3B8468BDFBB4-ble-arcore-log", "2025-03-22_15-21-58-898A3D98-CDCA-4AF4-BC2B-F92AF9F3F375-ble-arcore-log", "2025-03-22_15-24-40-BC2F8C57-AF95-4BC6-9F87-9E93E2C026E8-ble-arcore-log", "2025-03-22_15-27-47-15D3412B-80E1-407D-B9C0-EA8DA57E1097-ble-arcore-log"]
}
ARCORE_SCAN_GROUP = ScanGroup(Scan.load(f"{ARCORE_LOG_DIR}/{ARCORE_FIRST_SCAN}.json"))
for environmentID, filenames in ARCORE_SCANS.items():
    ARCORE_SCAN_GROUP.addScans(environmentID, [ Scan.load(f"{ARCORE_LOG_DIR}/{filename}.json") for filename in filenames])

ARCORE2_FIRST_SCAN = "2025-03-22_16-46-15-80B00C34-E960-4B12-9D0C-D5131EC4A466-ble-arcore-log"
ARCORE2_SCANS = {
    3: ["2025-03-22_16-47-15-EF92882E-D70F-4163-A704-7865CE1A2540-ble-arcore-log", "2025-03-22_16-47-50-D0736BFF-6859-4DB5-B804-DC47EB231A3A-ble-arcore-log", "2025-03-22_16-48-29-5B6B4472-5AE8-4C06-81D2-65E99DC72205-ble-arcore-log", "2025-03-22_16-49-12-49128766-FF7C-4B8C-BC99-0C9853FDA56B-ble-arcore-log", "2025-03-22_16-50-04-6DA18A42-BE8D-4DC6-9A8E-86436E5D6F43-ble-arcore-log"],
}
UWB_SCAN_GROUP = ScanGroup(Scan.load(f"{UWB_LOG_DIR}/{UWB_FIRST_SCAN}.json"))
for environmentID, filenames in UWB_SCANS.items():
    UWB_SCAN_GROUP.addScans(environmentID, [ Scan.load(f"{UWB_LOG_DIR}/{filename}.json") for filename in filenames])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#       1 ARKIT_FIRST_SCAN = "2025-03-22_00-03-51-FBFABD0F-E491-45C9-AB07-CC3295524EC5-ble-arkit-log"
#       2 ARKIT_SCANS = {
#       3     0: ["2025-03-22_00-10-32-9A8E41D0-08AD-43F6-9FC3-B103B32E3E7B-ble-arkit-log", "2025-03-22_00-16-36-8BD13323-9CC8-4072-8250-A4BFD3ABCF96-ble-arkit-log", "2025-03-22_00-20-26-2D7A0C99-5938-478D-94F4-70E2A051B1D9-ble-arkit-log", "2025-03-22_00-31-37-F93B686A-4004-4C7B-9B16-27AB9919B2B7-ble-arkit-log", "2025-03-22_00-32-47-2152F7F7-ECA9-42E0-BA21-97367274C5D3-ble-arkit-log"],
# ...

# %%
program_order = ["BLE-Assist (ARWorldMap)", "BLE-Assist (Cloud Anchors)", "UWB-Assist"]

import seaborn as sns
palette = sns.color_palette("deep", len(program_order))
palette
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196)]

# %%
import pandas as pd

rows = []
for env_id, delays in ARKIT_SCAN_GROUP.getFirstObjectDelays().items():
    for delay in delays:
        rows.append({
            'environmentId': env_id,
            'delay': delay,
            'program': 'BLE-Assist (ARWorldMap)'
        })

for env_id, delays in ARCORE_SCAN_GROUP.getFirstObjectDelays().items():
    for delay in delays:
        rows.append({
            'environmentId': env_id,
            'delay': delay,
            'program': 'BLE-Assist (Cloud Anchors)'
        })

for env_id, delays in ARCORE2_SCAN_GROUP.getFirstObjectDelays().items():
    for delay in delays:
        rows.append({
            'environmentId': env_id,
            'delay': delay,
            'program': 'BLE-Assist (Cloud Anchors)'
        })

for env_id, delays in UWB_SCAN_GROUP.getFirstObjectDelays().items():
    for delay in delays:
        rows.append({
            'environmentId': env_id,
            'delay': delay,
            'program': 'UWB-Assist'
        })

delay_df = pd.DataFrame(rows)
delay_df.sort_values(by=['environmentId']).tail()
# Out:
#      environmentId      delay                  program
# 83              19   5.717932  BLE-Assist (ARWorldMap)
# 84              19   5.210614  BLE-Assist (ARWorldMap)
# 85              19  11.521722  BLE-Assist (ARWorldMap)
# 87              19  10.192868  BLE-Assist (ARWorldMap)
# 241             19  23.677410               UWB-Assist

# %%
import matplotlib.pyplot as plt

# %%
count_df = delay_df.groupby(['environmentId', 'program']).size().reset_index(name='count')
all_combinations = pd.MultiIndex.from_product(
    [delay_df['environmentId'].unique(), delay_df['program'].unique()],
    names=['environmentId', 'program']
)
count_df = count_df.set_index(['environmentId', 'program']).reindex(all_combinations, fill_value=0).reset_index()
count_df = count_df[(count_df['environmentId'] >= 3) & (count_df['environmentId'] <= 18)]
count_df['success_rate'] = count_df['count'] / 5

spacial_program_order = [program_order[2], program_order[0], program_order[1]]
spacial_palette = [palette[2], palette[0], palette[1]]  

sns.lineplot(data=count_df, x='environmentId', y='success_rate', hue='program', palette=spacial_palette, hue_order=spacial_program_order, alpha=1, marker='X')

plt.title('Success Rate of Resloving the Anchor')
plt.xlabel('Environment Alteration')
plt.ylabel('Success Rate')
plt.legend(title='AR Sync Approach')

plt.xticks([3, 18], ['Hosting \nEnvironment', 'Heavily Altered \nEnvironment'])

plt.show()

# %%
sns.scatterplot(data=delay_df, x='environmentId', y='delay', hue='program', palette=palette, hue_order=program_order, alpha=1)

plt.title('Localization Delay')
plt.xlabel('Environment ID (Vision Features)')
plt.ylabel('Delay (sec)')
plt.legend(title='AR Sync Approach')

plt.show()

# %%
mean_df = delay_df.groupby(['environmentId', 'program'], as_index=False)['delay'].mean()
sns.scatterplot(data=mean_df, x='environmentId', y='delay', hue='program', palette=palette, hue_order=program_order, marker='X')

plt.title('Mean Localization Delay')
plt.xlabel('Environment ID (Vision Features)')
plt.ylabel('Delay (sec)')
plt.legend(title='AR Sync Approach')

plt.show()

# %%
data = mean_df[(mean_df['environmentId'] >= 3) & (mean_df['environmentId'] <= 18)]
sns.scatterplot(data=data, x='environmentId', y='delay', hue='program', palette=palette, hue_order=program_order, marker='X')

plt.title('Mean Localization Delay')
plt.xlabel('Environment Alteration')
plt.ylabel('Delay (sec)')
plt.legend(title='AR Sync Approach')

plt.xticks([3, 18], ['Hosting \nEnvironment', 'Heavily Altered \nEnvironment'])

plt.show()

# %%
print("Mean Localization Delay By Progra (sec)")
delay_df.groupby("program")['delay'].mean()
# Out:
# Mean Localization Delay By Progra (sec)
# program
# BLE-Assist (ARWorldMap)       13.274882
# BLE-Assist (Cloud Anchors)    39.642850
# UWB-Assist                    25.157003
# Name: delay, dtype: float64

# %%
rows = []
for env_id, distances in ARKIT_SCAN_GROUP.calculateDistance().items():
    for distance in distances:
        rows.append({
            'environmentId': env_id,
            'position_diff': distance['position'],
            'orientation_diff': distance['orientation'],
            'scale_diff': distance['scale'],
            'program': 'BLE-Assist (ARWorldMap)'
        })

for env_id, distances in ARCORE_SCAN_GROUP.calculateDistance().items():
    for distance in distances:
        rows.append({
            'environmentId': env_id,
            'position_diff': distance['position'],
            'orientation_diff': distance['orientation'],
            'scale_diff': distance['scale'],
            'program': 'BLE-Assist (Cloud Anchors)'
        })

for env_id, distances in ARCORE2_SCAN_GROUP.calculateDistance().items():
    for distance in distances:
        rows.append({
            'environmentId': env_id,
            'position_diff': distance['position'],
            'orientation_diff': distance['orientation'],
            'scale_diff': distance['scale'],
            'program': 'BLE-Assist (Cloud Anchors)'
        })

for env_id, distances in UWB_SCAN_GROUP.calculateDistance().items():
    for distance in distances:
        rows.append({
            'environmentId': env_id,
            'position_diff': distance['position'],
            'orientation_diff': distance['orientation'],
            'scale_diff': distance['scale'],
            'program': 'UWB-Assist'
        })

accuracy_df = pd.DataFrame(rows)
accuracy_df.sort_values(by=['environmentId']).tail()
# Out:
#      environmentId  position_diff  orientation_diff    scale_diff  \
# 83              19       0.013589          0.020120  4.680039e-07
# 84              19       0.017379          0.016190  1.992888e-07
# 85              19       0.017898          0.028706  2.090177e-07
# 87              19       0.010380          0.013160  2.317268e-07
# 241             19       0.063103          0.144230  1.576673e-07
#
#                      program
# 83   BLE-Assist (ARWorldMap)
# 84   BLE-Assist (ARWorldMap)
# 85   BLE-Assist (ARWorldMap)
# 87   BLE-Assist (ARWorldMap)
# 241               UWB-Assist

# %%
sns.scatterplot(data=accuracy_df, x='environmentId', y='position_diff', hue='program', palette=palette, hue_order=program_order, alpha=1)

plt.title('Position Accuracy')
plt.xlabel('Environment ID (Vision Features)')
plt.ylabel('Position Error <Euclidean Distance> (meters)')
plt.legend(title='AR Sync Approach')

plt.show()

# %%
mean_df = accuracy_df.groupby(['environmentId', 'program'], as_index=False)['position_diff'].mean()
sns.scatterplot(data=mean_df, x='environmentId', y='position_diff', hue='program', palette=palette, hue_order=program_order, marker='X')

plt.title('Mean Position Accuracy')
plt.xlabel('Environment ID (Vision Features)')
plt.ylabel('Position Error <Euclidean Distance> (metres)')
plt.legend(title='AR Sync Approach')

plt.show()

# %%
data = mean_df[(mean_df['environmentId'] >= 3) & (mean_df['environmentId'] <= 18)]
sns.scatterplot(data=data, x='environmentId', y='position_diff', hue='program', palette=palette, hue_order=program_order, marker='X')

plt.title('Mean Position Accuracy')
plt.xlabel('Environment Alteration')
plt.ylabel('Position Error <Euclidean Distance> (metres)')
plt.legend(title='AR Sync Approach')

plt.xticks([3, 18], ['Hosting \nEnvironment', 'Heavily Altered \nEnvironment'])

plt.show()

# %%
print("Mean Position Accuracy By Program (metres)")
accuracy_df.groupby("program")['position_diff'].mean()
# Out:
# Mean Position Accuracy By Program (metres)
# program
# BLE-Assist (ARWorldMap)       0.021092
# BLE-Assist (Cloud Anchors)    0.024853
# UWB-Assist                    0.071513
# Name: position_diff, dtype: float64

# %%
sns.scatterplot(data=accuracy_df, x='environmentId', y='orientation_diff', hue='program', palette=palette, hue_order=program_order, alpha=1)

plt.title('Orientation Accuracy')
plt.xlabel('Environment ID (Vision Features)')
plt.ylabel('Orientation Error <Angle Diff> (rad)')
plt.legend(title='AR Sync Approach')

plt.show()

# %%
mean_df = accuracy_df.groupby(['environmentId', 'program'], as_index=False)['orientation_diff'].mean()
sns.scatterplot(data=mean_df, x='environmentId', y='orientation_diff', hue='program', palette=palette, hue_order=program_order, marker='X')

plt.title('Mean Orientation Accuracy')
plt.xlabel('Environment ID (Vision Features)')
plt.ylabel('Orientation Error <Angle Diff> (rad)')
plt.legend(title='AR Sync Approach')

plt.show()

# %%
data = mean_df[(mean_df['environmentId'] >= 3) & (mean_df['environmentId'] <= 18)]
sns.scatterplot(data=data, x='environmentId', y='orientation_diff', hue='program', palette=palette, hue_order=program_order, marker='X')

plt.title('Mean Orientation Accuracy')
plt.xlabel('Environment Alteration)')
plt.ylabel('Orientation Error <Angle Diff> (rad)')
plt.legend(title='AR Sync Approach')

plt.xticks([3, 18], ['Hosting \nEnvironment', 'Heavily Altered \nEnvironment'])

plt.show()

# %%
print("Mean Orientation Accuracy By Program (rad)")
accuracy_df.groupby("program")['orientation_diff'].mean()
# Out:
# Mean Orientation Accuracy By Program (rad)
# program
# BLE-Assist (ARWorldMap)       0.022878
# BLE-Assist (Cloud Anchors)    0.030771
# UWB-Assist                    0.105818
# Name: orientation_diff, dtype: float64

# %%
sns.scatterplot(data=accuracy_df, x='environmentId', y='scale_diff', hue='program', palette=palette, hue_order=program_order, alpha=1)

plt.title('Scale Accuracy (Ideally 0)')
plt.xlabel('Environment ID (Vision Features)')
plt.ylabel('Scale Error <Euclidean Distance> (x)')
plt.legend(title='AR Sync Approach')

plt.show()

# %%
mean_df = accuracy_df.groupby(['environmentId', 'program'], as_index=False)['scale_diff'].mean()
sns.scatterplot(data=mean_df, x='environmentId', y='scale_diff', hue='program', palette=palette, hue_order=program_order, marker='X')

plt.title('Mean Scale Accuracy (Ideally 0)')
plt.xlabel('Environment ID (Vision Features)')
plt.ylabel('Scale Error <Euclidean Distance> (x)')
plt.legend(title='AR Sync Approach')

plt.show()

# %%
print("Mean Scale Accuracy By Program (x, ideally 0)")
accuracy_df.groupby("program")['scale_diff'].mean()
# Out:
# Mean Scale Accuracy By Program (x, ideally 0)
# program
# BLE-Assist (ARWorldMap)       3.693609e-07
# BLE-Assist (Cloud Anchors)    2.064159e-07
# UWB-Assist                    2.894378e-07
# Name: scale_diff, dtype: float64
